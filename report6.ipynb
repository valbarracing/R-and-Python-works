# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Parámetros
Y_size = 100 
b = 0.2                 #propensión marginal a consumir
m = 0.2                 #propensión a importar
t = 1                   #tasa impositiva
Co = 20                 #consumo autónomo
Io = 10                  #inversión autónoma
Go = 8                  #gasto gobierno 
Xo = 2                  #exportación 
h =  5                  #constante de decisión a invertir

Y = np.arange(Y_size)

# %%
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

def Y_IS(b, m, t, Co, Io, Go, Xo, h, r):
    Y_IS = (Co + Io + Go + Xo - h*r)/(1-(b-m)*(1-t))
    return Y_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)
r
# Out:
# array([  8. ,   7.8,   7.6,   7.4,   7.2,   7. ,   6.8,   6.6,   6.4,
#          6.2,   6. ,   5.8,   5.6,   5.4,   5.2,   5. ,   4.8,   4.6,
#          4.4,   4.2,   4. ,   3.8,   3.6,   3.4,   3.2,   3. ,   2.8,
#          2.6,   2.4,   2.2,   2. ,   1.8,   1.6,   1.4,   1.2,   1. ,
#          0.8,   0.6,   0.4,   0.2,   0. ,  -0.2,  -0.4,  -0.6,  -0.8,
#         -1. ,  -1.2,  -1.4,  -1.6,  -1.8,  -2. ,  -2.2,  -2.4,  -2.6,
#         -2.8,  -3. ,  -3.2,  -3.4,  -3.6,  -3.8,  -4. ,  -4.2,  -4.4,
#         -4.6,  -4.8,  -5. ,  -5.2,  -5.4,  -5.6,  -5.8,  -6. ,  -6.2,
#         -6.4,  -6.6,  -6.8,  -7. ,  -7.2,  -7.4,  -7.6,  -7.8,  -8. ,
#         -8.2,  -8.4,  -8.6,  -8.8,  -9. ,  -9.2,  -9.4,  -9.6,  -9.8,
#        -10. , -10.2, -10.4, -10.6, -10.8, -11. , -11.2, -11.4, -11.6,
#        -11.8])

# %%
y_max = np.max(r)
x_max = Y_IS(b, m, t, Co, Io, Go, Xo, h, 0)

v = [0, x_max, 0, y_max]                        
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="IS SCHEDULE", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, r, "k-")
ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())   
plt.axis(v)                                    
plt.show()

# %%
Go_1 = 14

def r_IS_1(b, m, t, Co, Io, Go_1, Xo, h, Y):
    r_IS_1 = (Co + Io + Go_1 + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS_1

def Y_IS_1(b, m, t, Co, Io, Go_1, Xo, h, r_1):
    Y_IS_1 = (Co + Io + Go_1 + Xo - h*r)/(1-(b-m)*(1-t))
    return Y_IS_1

r_1 = r_IS_1(b, m, t, Co, Io, Go_1, Xo, h, Y)
r_1
# Out:
# array([  9.2,   9. ,   8.8,   8.6,   8.4,   8.2,   8. ,   7.8,   7.6,
#          7.4,   7.2,   7. ,   6.8,   6.6,   6.4,   6.2,   6. ,   5.8,
#          5.6,   5.4,   5.2,   5. ,   4.8,   4.6,   4.4,   4.2,   4. ,
#          3.8,   3.6,   3.4,   3.2,   3. ,   2.8,   2.6,   2.4,   2.2,
#          2. ,   1.8,   1.6,   1.4,   1.2,   1. ,   0.8,   0.6,   0.4,
#          0.2,   0. ,  -0.2,  -0.4,  -0.6,  -0.8,  -1. ,  -1.2,  -1.4,
#         -1.6,  -1.8,  -2. ,  -2.2,  -2.4,  -2.6,  -2.8,  -3. ,  -3.2,
#         -3.4,  -3.6,  -3.8,  -4. ,  -4.2,  -4.4,  -4.6,  -4.8,  -5. ,
#         -5.2,  -5.4,  -5.6,  -5.8,  -6. ,  -6.2,  -6.4,  -6.6,  -6.8,
#         -7. ,  -7.2,  -7.4,  -7.6,  -7.8,  -8. ,  -8.2,  -8.4,  -8.6,
#         -8.8,  -9. ,  -9.2,  -9.4,  -9.6,  -9.8, -10. , -10.2, -10.4,
#        -10.6])

# %%
y_max = np.max(r)
x_max = Y_IS(b, m, t, Co, Io, Go, Xo, h, 0)

v = [0, x_max, 0, y_max]                        
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="IS SCHEDULE", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, r, "k-")
ax.plot(Y, r_1, "k-", linestyle = 'dashed', color = 'red')
ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())   
plt.axis(v)                                    
plt.show()
# Out:
# /var/folders/t0/bh8jstj91y5ctmcqzzd24zyc0000gn/T/ipykernel_3060/493351193.py:8: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, r_1, "k-", linestyle = 'dashed', color = 'red')
# /var/folders/t0/bh8jstj91y5ctmcqzzd24zyc0000gn/T/ipykernel_3060/493351193.py:8: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(Y, r_1, "k-", linestyle = 'dashed', color = 'red')

# %%
t_2 = 0.3

def r_IS_2(b, m, t_2, Co, Io, Go, Xo, h, Y):
    r_IS_2 = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t_2)))/h
    return r_IS_2

def Y_IS_2(b, m, t_2, Co, Io, Go, Xo, h, r_1):
    Y_IS_2 = (Co + Io + Go + Xo - h*r)/(1-(b-m)*(1-t_2))
    return Y_IS_2

r_2 = r_IS_2(b, m, t_2, Co, Io, Go, Xo, h, Y)
r_2
# Out:
# array([  8. ,   7.8,   7.6,   7.4,   7.2,   7. ,   6.8,   6.6,   6.4,
#          6.2,   6. ,   5.8,   5.6,   5.4,   5.2,   5. ,   4.8,   4.6,
#          4.4,   4.2,   4. ,   3.8,   3.6,   3.4,   3.2,   3. ,   2.8,
#          2.6,   2.4,   2.2,   2. ,   1.8,   1.6,   1.4,   1.2,   1. ,
#          0.8,   0.6,   0.4,   0.2,   0. ,  -0.2,  -0.4,  -0.6,  -0.8,
#         -1. ,  -1.2,  -1.4,  -1.6,  -1.8,  -2. ,  -2.2,  -2.4,  -2.6,
#         -2.8,  -3. ,  -3.2,  -3.4,  -3.6,  -3.8,  -4. ,  -4.2,  -4.4,
#         -4.6,  -4.8,  -5. ,  -5.2,  -5.4,  -5.6,  -5.8,  -6. ,  -6.2,
#         -6.4,  -6.6,  -6.8,  -7. ,  -7.2,  -7.4,  -7.6,  -7.8,  -8. ,
#         -8.2,  -8.4,  -8.6,  -8.8,  -9. ,  -9.2,  -9.4,  -9.6,  -9.8,
#        -10. , -10.2, -10.4, -10.6, -10.8, -11. , -11.2, -11.4, -11.6,
#        -11.8])

# %%
y_max = np.max(r)
x_max = Y_IS(b, m, t, Co, Io, Go, Xo, h, 0)

v = [0, x_max, 0, y_max]                        
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="IS SCHEDULE", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, r, "k-")
ax.plot(Y, r_2, "k-", linestyle = 'dashed', color = 'blue')
ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())   
plt.axis(v)                                    
plt.show()
# Out:
# /var/folders/t0/bh8jstj91y5ctmcqzzd24zyc0000gn/T/ipykernel_3060/3729916710.py:8: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, r_2, "k-", linestyle = 'dashed', color = 'blue')
# /var/folders/t0/bh8jstj91y5ctmcqzzd24zyc0000gn/T/ipykernel_3060/3729916710.py:8: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(Y, r_2, "k-", linestyle = 'dashed', color = 'blue')
